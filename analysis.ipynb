# %% [markdown]
# # Data → Statistics → LLM Story Generation (Two Versions for Misty)
# This notebook outlines the workflow for:
# 1. Loading data
# 2. Computing statistics
# 3. Formatting statistics into text
# 4. Sending statistics to an LLM
# 5. Generating two versions of the story:
#    - **Neutral story**
#    - **Robot-enhanced story** including *actions, gestures, expressions, LED colors, and movements* for Misty

# %%
# Step 1: Import necessary libraries
# (Placeholder for imports such as pandas, numpy, etc.)

# %%
# Step 2: Load the dataset
# (Placeholder for loading CSV, Excel, or database files)

# %%
# Step 3: Basic inspection of the dataset/Cleaning the dataset
# - df.head()
# - df.info()
# - df.describe()
# - Missing values and duplicates

# %%
# Step 4: Compute summary statistics
# - Mean, median, max, min
# - Value counts
# - Group-by statistics
# - Any custom metrics needed for storytelling

# %%
# Step 5: Extract key statistics for LLM
# - Build a text summary of the important metrics
# Example:
# stats_summary = f"Average: {avg}, Highest value: {max_val}, ..."

# %%
# Step 6: Create LLM prompt for story generation
# Example neutral prompt:
# neutral_prompt = f"Using the following statistics, write a neutral narrative: {stats_summary}"

# %%
# Step 7: Create LLM prompt for robot-enhanced Misty story
# Example robot-enhanced prompt:
# robot_prompt = (
#     f"Using these statistics, write a story for Misty. "
#     f"Include gestures, animations, arm movements, expressions, and LED colors. "
#     f"Here are the statistics: {stats_summary}"
# )

# %%
# Step 8: Send both prompts to an LLM 
# - Call your model API (OpenAI, Gemini, Claude, etc.)
# - Collect both story versions

# %%
# Step 9: Program Misty to perform both versions of the story
# - Using the robot-enhanced story, map out Misty's actions
# - Implement the neutral story as a baseline performance

# %% [markdown]
# ## Step 9: Conclusions
# - Review neutral vs. robot-enhanced versions
# - Adjust prompts or storytelling style
# - Document observations and next steps
